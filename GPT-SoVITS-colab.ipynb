# %% [markdown]
# <a href="https://colab.research.google.com/github/oosennpai/invoiceninja/blob/v5-stable/GPT-SoVITS-colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 👇 Just Click the Play Button (Run) and Wait for Public Gradio Link

# %%
# @title Do Everything For Me and Launch Gradio
# %cd /content
# !git clone https://github.com/RVC-Boss/GPT-SoVITS
# %cd /content/GPT-SoVITS

# !conda install -c conda-forge gcc gxx ffmpeg cmake
# !conda install pytorch==2.1.1 torchvision==0.16.1 torchaudio==2.1.1 pytorch-cuda=11.8 -c pytorch -c nvidia

# !pip install pyyaml  # This addresses the ModuleNotFoundError for yaml
# !pip install numba==0.56.4  # Trying to install numba separately to see if it resolves the issue

# !pip install -r requirements.txt

# !python webui.py
# Out:
# /content
# Cloning into 'GPT-SoVITS'...
# remote: Enumerating objects: 5902, done.
# remote: Counting objects: 100% (63/63), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 5902 (delta 36), reused 14 (delta 14), pack-reused 5839 (from 3)
# Receiving objects: 100% (5902/5902), 14.16 MiB | 7.33 MiB/s, done.
# Resolving deltas: 100% (3368/3368), done.
# /content/GPT-SoVITS
# /bin/bash: line 1: conda: command not found
# /bin/bash: line 1: conda: command not found
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 82.9 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# ...

# %%
# !pip install ffmpeg-python -q
print("✅ 完了")
# Out:
# ✅ 完了

# %%
import os, subprocess, time

env = os.environ.copy()
env["PYTHONPATH"] = "/content/GPT-SoVITS:/content/GPT-SoVITS/GPT_SoVITS"
proc = subprocess.Popen(
    ["python", "GPT_SoVITS/inference_webui.py"],
    cwd="/content/GPT-SoVITS",
    stdout=open("/tmp/tts.log", "w"),
    stderr=subprocess.STDOUT,
    env=env
)
time.sleep(60)

from pyngrok import ngrok, conf
conf.get_default().auth_token = "3CZVatQVATP4u5W9jPJ05nTOvXK_4qtth9k1i2pgPdpogW6hn"
ngrok.kill()
tunnel = ngrok.connect(9872, "http")
print("=" * 50)
print("✅ URL:")
print(tunnel.public_url)
print("=" * 50)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_4372/107833675.py in <cell line: 0>()
#      12 time.sleep(60)
#      13
# ---> 14 from pyngrok import ngrok, conf
#      15 conf.get_default().auth_token = "3CZVatQVATP4u5W9jPJ05nTOvXK_4qtth9k1i2pgPdpogW6hn"
#      16 ngrok.kill()
#
# ModuleNotFoundError: No module named 'pyngrok'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install pyngrok pydub ffmpeg-python -q
print("✅ 完了")
# Out:
# ✅ 完了

# %%
import os, subprocess, time

env = os.environ.copy()
env["PYTHONPATH"] = "/content/GPT-SoVITS:/content/GPT-SoVITS/GPT_SoVITS"
proc = subprocess.Popen(
    ["python", "GPT_SoVITS/inference_webui.py"],
    cwd="/content/GPT-SoVITS",
    stdout=open("/tmp/tts.log", "w"),
    stderr=subprocess.STDOUT,
    env=env
)
time.sleep(60)

from pyngrok import ngrok, conf
conf.get_default().auth_token = "3CZVatQVATP4u5W9jPJ05nTOvXK_4qtth9k1i2pgPdpogW6hn"
ngrok.kill()
tunnel = ngrok.connect(9872, "http")
print("=" * 50)
print("✅ URL:")
print(tunnel.public_url)
print("=" * 50)
# Out:
# ...
# ✅ URL:
# https://platonic-slouchy-posted.ngrok-free.dev
# ...

# %%
import socket, time

for i in range(18):
    s = socket.socket()
    s.settimeout(2)
    result = s.connect_ex(('127.0.0.1', 9872))
    s.close()
    if result == 0:
        print(f"✅ ポート9872 開通！")
        break
    print(f"待機中... {i*10}秒")
    time.sleep(10)
else:
    print("❌ 開かなかった")
    # !tail -5 /tmp/tts.log
# Out:
# 待機中... 0秒
# 待機中... 10秒
# 待機中... 20秒
# 待機中... 30秒
# 待機中... 40秒
# 待機中... 50秒
# 待機中... 60秒
# 待機中... 70秒
# 待機中... 80秒
# 待機中... 90秒
# 待機中... 100秒
# 待機中... 110秒
# 待機中... 120秒
# 待機中... 130秒
# 待機中... 140秒
# 待機中... 150秒
# 待機中... 160秒
# 待機中... 170秒
# ❌ 開かなかった
#   File "/content/GPT-SoVITS/GPT_SoVITS/text/LangSegmenter/__init__.py", line 1, in <module>
#     from .langsegmenter import LangSegmenter
#   File "/content/GPT-SoVITS/GPT_SoVITS/text/LangSegmenter/langsegmenter.py", line 10, in <module>
#     import fast_langdetect
# ModuleNotFoundError: No module named 'fast_langdetect'

# %%
# !tail -10 /tmp/tts.log
# Out:
# /content/GPT-SoVITS/GPT_SoVITS/inference_webui.py:1104: SyntaxWarning: invalid escape sequence '\d'
#   parts = re.split("(\d+)", s)
# Traceback (most recent call last):
#   File "/content/GPT-SoVITS/GPT_SoVITS/inference_webui.py", line 33, in <module>
#     from text.LangSegmenter import LangSegmenter
#   File "/content/GPT-SoVITS/GPT_SoVITS/text/LangSegmenter/__init__.py", line 1, in <module>
#     from .langsegmenter import LangSegmenter
#   File "/content/GPT-SoVITS/GPT_SoVITS/text/LangSegmenter/langsegmenter.py", line 10, in <module>
#     import fast_langdetect
# ModuleNotFoundError: No module named 'fast_langdetect'

# %%
# !pip install fast-langdetect -q
print("✅ 完了")
# Out:
# ✅ 完了

# %%
import os, subprocess, time

os.makedirs("/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/fast_langdetect", exist_ok=True)

env = os.environ.copy()
env["PYTHONPATH"] = "/content/GPT-SoVITS:/content/GPT-SoVITS/GPT_SoVITS"
proc = subprocess.Popen(
    ["python", "GPT_SoVITS/inference_webui.py"],
    cwd="/content/GPT-SoVITS",
    stdout=open("/tmp/tts.log", "w"),
    stderr=subprocess.STDOUT,
    env=env
)
print(f"起動中... PID: {proc.pid}")
time.sleep(60)

import socket
s = socket.socket()
s.settimeout(2)
result = s.connect_ex(('127.0.0.1', 9872))
s.close()
if result == 0:
    print("✅ ポート9872 開通！")
else:
    print("❌ まだ開いていない")
    # !tail -5 /tmp/tts.log
# Out:
# 起動中... PID: 10312
# ❌ まだ開いていない
#   File "/content/GPT-SoVITS/GPT_SoVITS/text/LangSegmenter/__init__.py", line 1, in <module>
#     from .langsegmenter import LangSegmenter
#   File "/content/GPT-SoVITS/GPT_SoVITS/text/LangSegmenter/langsegmenter.py", line 14, in <module>
#     from split_lang import LangSplitter
# ModuleNotFoundError: No module named 'split_lang'

# %%
# !pip install fast-langdetect split-lang ffmpeg-python pyngrok pydub -q
print("✅ 完了")
# Out:
# ✅ 完了

# %%
import os, subprocess, time

os.makedirs("/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/fast_langdetect", exist_ok=True)

env = os.environ.copy()
env["PYTHONPATH"] = "/content/GPT-SoVITS:/content/GPT-SoVITS/GPT_SoVITS"
proc = subprocess.Popen(
    ["python", "GPT_SoVITS/inference_webui.py"],
    cwd="/content/GPT-SoVITS",
    stdout=open("/tmp/tts.log", "w"),
    stderr=subprocess.STDOUT,
    env=env
)
print(f"起動中... PID: {proc.pid}")
time.sleep(60)

import socket
s = socket.socket()
s.settimeout(2)
result = s.connect_ex(('127.0.0.1', 9872))
s.close()
if result == 0:
    print("✅ ポート9872 開通！")
else:
    print("❌ まだ開いていない")
    # !tail -5 /tmp/tts.log
# Out:
# 起動中... PID: 10889
# ❌ まだ開いていない
#   File "/content/GPT-SoVITS/GPT_SoVITS/f5_tts/model/__init__.py", line 4, in <module>
#     from GPT_SoVITS.f5_tts.model.backbones.dit import DiT
#   File "/content/GPT-SoVITS/GPT_SoVITS/f5_tts/model/backbones/dit.py", line 16, in <module>
#     from x_transformers.x_transformers import RotaryEmbedding
# ModuleNotFoundError: No module named 'x_transformers'

# %%
# !pip install fast-langdetect split-lang ffmpeg-python pyngrok pydub x-transformers torch torchaudio -q
print("✅ 完了")
# Out:
# ✅ 完了

# %%
import os, subprocess, time

os.makedirs("/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/fast_langdetect", exist_ok=True)

env = os.environ.copy()
env["PYTHONPATH"] = "/content/GPT-SoVITS:/content/GPT-SoVITS/GPT_SoVITS"
proc = subprocess.Popen(
    ["python", "GPT_SoVITS/inference_webui.py"],
    cwd="/content/GPT-SoVITS",
    stdout=open("/tmp/tts.log", "w"),
    stderr=subprocess.STDOUT,
    env=env
)
print(f"起動中... PID: {proc.pid}")
time.sleep(60)

import socket
s = socket.socket()
s.settimeout(2)
result = s.connect_ex(('127.0.0.1', 9872))
s.close()
if result == 0:
    print("✅ ポート9872 開通！")
else:
    print("❌ まだ開いていない")
    # !tail -5 /tmp/tts.log
# Out:
# 起動中... PID: 11598
# ❌ まだ開いていない
#   File "/content/GPT-SoVITS/GPT_SoVITS/inference_webui.py", line 121, in <module>
#     from AR.models.t2s_lightning_module import Text2SemanticLightningModule
#   File "/content/GPT-SoVITS/GPT_SoVITS/AR/models/t2s_lightning_module.py", line 11, in <module>
#     from pytorch_lightning import LightningModule
# ModuleNotFoundError: No module named 'pytorch_lightning'

# %%
# !pip install fast-langdetect split-lang ffmpeg-python pyngrok pydub x-transformers pytorch-lightning -q
print("✅ 完了")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 51.6 MB/s eta 0:00:00
# ✅ 完了

# %%
import os, subprocess, time

os.makedirs("/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/fast_langdetect", exist_ok=True)

env = os.environ.copy()
env["PYTHONPATH"] = "/content/GPT-SoVITS:/content/GPT-SoVITS/GPT_SoVITS"
proc = subprocess.Popen(
    ["python", "GPT_SoVITS/inference_webui.py"],
    cwd="/content/GPT-SoVITS",
    stdout=open("/tmp/tts.log", "w"),
    stderr=subprocess.STDOUT,
    env=env
)
print(f"起動中... PID: {proc.pid}")
time.sleep(90)

import socket
s = socket.socket()
s.settimeout(2)
result = s.connect_ex(('127.0.0.1', 9872))
s.close()
if result == 0:
    print("✅ ポート9872 開通！")
else:
    print("❌ まだ開いていない")
    # !tail -3 /tmp/tts.log
# Out:
# 起動中... PID: 12978
# ❌ まだ開いていない
#   File "/usr/local/lib/python3.12/dist-packages/transformers/utils/hub.py", line 468, in cached_files
#     raise OSError(f"{e}") from e
# OSError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': 'GPT_SoVITS/pretrained_models/chinese-roberta-wwm-ext-large'. Use `repo_type` argument if needed.

# %%
from huggingface_hub import snapshot_download

print("中国語モデルをダウンロード中...（2〜3分）")
snapshot_download(
    repo_id="hfl/chinese-roberta-wwm-ext-large",
    local_dir="/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/chinese-roberta-wwm-ext-large",
    local_dir_use_symlinks=False
)
print("✅ 完了")
# Out:
# 中国語モデルをダウンロード中...（2〜3分）
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py:205: UserWarning: The `local_dir_use_symlinks` argument is deprecated and ignored in `snapshot_download`. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# Fetching 11 files:   0%|          | 0/11 [00:00<?, ?it/s]
# ...

# %%
import os, subprocess, time

os.makedirs("/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/fast_langdetect", exist_ok=True)

env = os.environ.copy()
env["PYTHONPATH"] = "/content/GPT-SoVITS:/content/GPT-SoVITS/GPT_SoVITS"
proc = subprocess.Popen(
    ["python", "GPT_SoVITS/inference_webui.py"],
    cwd="/content/GPT-SoVITS",
    stdout=open("/tmp/tts.log", "w"),
    stderr=subprocess.STDOUT,
    env=env
)
print(f"起動中... PID: {proc.pid}")
time.sleep(90)

import socket
s = socket.socket()
s.settimeout(2)
result = s.connect_ex(('127.0.0.1', 9872))
s.close()
if result == 0:
    print("✅ ポート9872 開通！")
else:
    print("❌ まだ開いていない")
    # !tail -3 /tmp/tts.log
# Out:
# 起動中... PID: 14312
# ❌ まだ開いていない
#   File "/content/GPT-SoVITS/GPT_SoVITS/feature_extractor/cnhubert.py", line 30, in __init__
#     raise FileNotFoundError(base_path)
# FileNotFoundError: GPT_SoVITS/pretrained_models/chinese-hubert-base

# %%
from huggingface_hub import snapshot_download

print("ダウンロード中...（2〜3分）")
snapshot_download(
    repo_id="TencentGameMate/chinese-hubert-base",
    local_dir="/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/chinese-hubert-base",
    local_dir_use_symlinks=False
)
print("✅ 完了")
# Out:
# ダウンロード中...（2〜3分）
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py:205: UserWarning: The `local_dir_use_symlinks` argument is deprecated and ignored in `snapshot_download`. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# ...
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# ✅ 完了

# %%
import os, subprocess, time

os.makedirs("/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/fast_langdetect", exist_ok=True)

env = os.environ.copy()
env["PYTHONPATH"] = "/content/GPT-SoVITS:/content/GPT-SoVITS/GPT_SoVITS"
proc = subprocess.Popen(
    ["python", "GPT_SoVITS/inference_webui.py"],
    cwd="/content/GPT-SoVITS",
    stdout=open("/tmp/tts.log", "w"),
    stderr=subprocess.STDOUT,
    env=env
)
print(f"起動中... PID: {proc.pid}")
time.sleep(90)

import socket
s = socket.socket()
s.settimeout(2)
result = s.connect_ex(('127.0.0.1', 9872))
s.close()
if result == 0:
    print("✅ ポート9872 開通！")
else:
    print("❌ まだ開いていない")
    # !tail -3 /tmp/tts.log
# Out:
# 起動中... PID: 15227
# ❌ まだ開いていない
#     super().__init__(open(name, mode))  # noqa: SIM115
#                      ^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: ''

# %%
# !tail -20 /tmp/tts.log
# Out:
# /content/GPT-SoVITS/GPT_SoVITS/inference_webui.py:1104: SyntaxWarning: invalid escape sequence '\d'
#   parts = re.split("(\d+)", s)
# ...
# Loading weights: 100%|██████████| 211/211 [00:00<00:00, 4185.32it/s, Materializing param=masked_spec_embed]
# Traceback (most recent call last):
#   File "/content/GPT-SoVITS/GPT_SoVITS/inference_webui.py", line 400, in <module>
#     change_gpt_weights(gpt_path)
#   File "/content/GPT-SoVITS/GPT_SoVITS/inference_webui.py", line 381, in change_gpt_weights
#     dict_s1 = torch.load(gpt_path, map_location="cpu", weights_only=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 1500, in load
#     with _open_file_like(f, "rb") as opened_file:
#          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 768, in _open_file_like
#     return _open_file(name_or_buffer, mode)
# ...

# %%
# ===== 次回起動用セル =====
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

import os, subprocess, time

print("【1/3】Driveから復元中...（3〜5分）")
# !cp -r /content/drive/MyDrive/GPT-SoVITS-backup/GPT-SoVITS /content/
print("✅ 完了")

print("【2/3】ライブラリインストール中...")
# !cd /content/GPT-SoVITS && pip install -r requirements_no_opencc.txt -q
# !pip install pyngrok pydub ffmpeg-python -q
print("✅ 完了")

print("【3/3】サーバー起動中...")
env = os.environ.copy()
env["PYTHONPATH"] = "/content/GPT-SoVITS:/content/GPT-SoVITS/GPT_SoVITS"
proc = subprocess.Popen(
    ["python", "GPT_SoVITS/inference_webui.py"],
    cwd="/content/GPT-SoVITS",
    stdout=open("/tmp/tts.log", "w"),
    stderr=subprocess.STDOUT,
    env=env
)
time.sleep(60)

from pyngrok import ngrok, conf
conf.get_default().auth_token = "3CZVatQVATP4u5W9jPJ05nTOvXK_4qtth9k1i2pgPdpogW6hn"
ngrok.kill()
tunnel = ngrok.connect(9872, "http")
print("=" * 50)
print("✅ URL:")
print(tunnel.public_url)
print("=" * 50)
